# %% [markdown]
# # TeleMemetry™ Memory Rail Demo
#
# Audience assumption: this analysis assumes you have a dedicated local AI or IDE agent with folder access to the extracted TeleMemetry evidence bundle. It is not designed for browser-chat upload verification.
#
# Preferred path: open the `memory-demo` secure link if the Launchable exposes port `7860`.
#
# Notebook fallback: click **Run All** to run the public reproduction benchmark and verify the result package.
#
# This demo generates 3,000 deterministic turns, verifies 1:1 recall, writes SHA256 receipts, and produces an AI-auditable result package under `results/latest`.

# %%
# !bash launch.sh

# %% [markdown]
# ## Next
#
# Open `results/latest/00_START_HERE.txt` first.
#
# Open `results/latest/01_QUICK_VALIDATION.txt` for the short validation brief.
#
# Open `results/latest/RESULT_SUMMARY.txt` for the plain-language summary.
#
# For independent AI review, extract or open `results/latest` as a folder in a local AI or IDE agent and ask it to inspect the files directly.
