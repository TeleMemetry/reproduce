# %% [markdown]
# # TeleMemetry™ Memory Rail Demo
#
# Click **Run All** to run the public reproduction benchmark and verify the result package.
#
# This demo generates 3,000 deterministic turns, verifies 1:1 recall, writes SHA256 receipts, and produces an AI-auditable result package under `results/latest`.

# %%
# !bash launch.sh

# %% [markdown]
# ## Next
#
# Open `results/latest/RESULT_SUMMARY.txt` for the plain-language summary.
#
# Open `results/latest/prompt.md`, paste it into ChatGPT, Codex, Claude, Gemini, or another AI assistant, and attach or paste the generated result files for review.
